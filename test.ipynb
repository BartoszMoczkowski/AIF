# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0,1,1000)
y = np.random.normal(0,1,1000)

plt.scatter(x,y)

# %%
w = np.random.rand(1,2)
inputs = np.random.rand(2,400)
classes = np.random.rand(1,400)

# %%
points = np.random.rand(4,2,4)

# %%
(w@points).shape
# Out:
# (4, 1, 4)

# %%
x = np.linspace(-1,1,10)
y = np.linspace(-1,1,10)

X,Y = np.meshgrid(x,y)

# %%
# Out:
# array([[-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ],
#        [-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#          0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ]])

# %%
w@points
# Out:
# array([[[0.83986063, 0.66265495, 1.15578084, 0.55432226]],
#
#        [[0.98414883, 0.42057895, 0.97092837, 0.44296002]],
#
#        [[0.239993  , 1.14719575, 0.17309714, 0.93643003]],
#
#        [[0.61998601, 0.23585196, 0.42975783, 1.28493769]]])

# %%
(w@inputs).shape
# Out:
# (1, 400)

# %%
(w.T@inputs).shape
# Out:
# (1, 400)

# %%
(classes.T.reshape((400,)) - w@inputs).shape
# Out:
# (400,)

# %%
(w@inputs).shape
# Out:
# (400,)

# %%
classes.T.shape
# Out:
# (400, 1)

# %%
w = np.array([[1,2],[3,4],[7,5]])
n = np.array([[1],[2]])

w@n
# Out:
# array([[ 5],
#        [11],
#        [17]])

# %%
n.T@w.T
# Out:
# array([[ 5, 11, 17]])

# %%
w.shape
# Out:
# (3, 2)

# %%
n.shape
# Out:
# (2, 1)
